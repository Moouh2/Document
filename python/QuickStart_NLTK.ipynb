# %% [markdown]
# #### Installation

# %%
#!pip install nltk

# %%
import nltk  # type: ignore
from tokenisation import tokens  # type: ignore

#from nltk.tokenize import word_tokenize
sentence = """At eight o'clock on Thursday morning
... Arthur didn't feel very good."""
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 2
#       1 import nltk
# ----> 2 from tokenisation import tokens  # type: ignore
#       4 #from nltk.tokenize import word_tokenize
#       5 sentence = """At eight o'clock on Thursday morning
#       6 ... Arthur didn't feel very good."""
#
# ModuleNotFoundError: No module named 'tokenisation'

# %%
nltk.download('punkt_tab')
#nltk.download('stopwords')
 #tokens = nltk.word_tokenize(sentence)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
tokens = nltk.word_tokenize(sentence)

# %%
tokens
# Out:
# ['At',
#  'eight',
#  "o'clock",
#  'on',
#  'Thursday',
#  'morning',
#  '...',
#  'Arthur',
#  'did',
#  "n't",
#  'feel',
#  'very',
#  'good',
#  '.']

# %%
tokens[0]
# Out:
# 'At'

# %%
tagged = nltk.pos_tag(tokens)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 tagged = nltk.pos_tag(tokens)
#
# File ~\anaconda\envs\env311\Lib\site-packages\nltk\tag\__init__.py:168, in pos_tag(tokens, tagset, lang)
#     143 def pos_tag(tokens, tagset=None, lang="eng"):
#     144     """
#     145     Use NLTK's currently recommended part of speech tagger to
#     146     tag the given list of tokens.
#    (...)    166     :rtype: list(tuple(str, str))
#     167     """
# --> 168     tagger = _get_tagger(lang)
#     169     return _pos_tag(tokens, tagset, tagger, lang)
#
# File ~\anaconda\envs\env311\Lib\site-packages\nltk\tag\__init__.py:110, in _get_tagger(lang)
#     108     tagger = PerceptronTagger(lang=lang)
#     109 else:
# --> 110     tagger = PerceptronTagger()
#     111 return tagger
#
# File ~\anaconda\envs\env311\Lib\site-packages\nltk\tag\perceptron.py:183, in PerceptronTagger.__init__(self, load, lang)
#     181 self.classes = set()
#     182 if load:
# --> 183     self.load_from_json(lang)
#
# File ~\anaconda\envs\env311\Lib\site-packages\nltk\tag\perceptron.py:273, in PerceptronTagger.load_from_json(self, lang)
#     271 def load_from_json(self, lang="eng"):
#     272     # Automatically find path to the tagger if location is not specified.
# --> 273     loc = find(f"taggers/averaged_perceptron_tagger_{lang}/")
#     274     with open(loc + TAGGER_JSONS[lang]["weights"]) as fin:
#     275         self.model.weights = json.load(fin)
#
# File ~\anaconda\envs\env311\Lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource averaged_perceptron_tagger_eng not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('averaged_perceptron_tagger_eng')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load taggers/averaged_perceptron_tagger_eng/
#
#   Searched in:
#     - 'C:\\Users\\hp/nltk_data'
#     - 'C:\\Users\\hp\\anaconda\\envs\\env311\\nltk_data'
#     - 'C:\\Users\\hp\\anaconda\\envs\\env311\\share\\nltk_data'
#     - 'C:\\Users\\hp\\anaconda\\envs\\env311\\lib\\nltk_data'
#     - 'C:\\Users\\hp\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
tagged
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 tagged
#
# NameError: name 'tagged' is not defined

# %%
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
entities = nltk.chunk.ne_chunk(tagged)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 3
#       1 nltk.download('maxent_ne_chunker_tab')
#       2 nltk.download('words')
# ----> 3 entities = nltk.chunk.ne_chunk(tagged)
#
# NameError: name 'tagged' is not defined

# %%
#!pip install svgling
entities
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 #!pip install svgling
# ----> 2 entities
#
# NameError: name 'entities' is not defined
