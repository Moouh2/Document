# %%
from bs4 import BeautifulSoup
import requests

# %%
url ='https://fr.wikipedia.org/wiki/Gabon'
page_examen = requests.get(url)
examen = BeautifulSoup(page_examen.text, 'html')

# %%
print(examen)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-toc-available" dir="ltr" lang="fr">
# <head>
# <meta charset="utf-8"/>
# <title>Gabon — Wikipédia</title>
# ...

# %%
<h5><span class="mw-headline" id="Parcs_nationaux">Parcs nationaux</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Gabon&amp;veaction=edit&amp;section=20" title="Modifier la section : Parcs nationaux" class="mw-editsection-visualeditor"><span>modifier</span></a><span class="mw-editsection-divider"> | </span><a href="/w/index.php?title=Gabon&amp;action=edit&amp;section=20" title="Modifier le code source de la section : Parcs nationaux"><span>modifier le code</span></a><span class="mw-editsection-bracket">]</span></span></h5>
<p>À l'occasion du <a href="/wiki/Sommet_mondial_sur_le_d%C3%A9veloppement_durable" title="Sommet mondial sur le développement durable">sommet de la Terre</a>, à <a href="/wiki/Johannesbourg" title="Johannesbourg">Johannesbourg</a>, en 2002, le Gabon a annoncé la création d'un réseau de 13 <a href="/wiki/Parc_national" title="Parc national">parcs nationaux</a>, couvrant au total plus de 10&nbsp;% du territoire du pays<sup id="cite_ref-afd_81-1" class="reference"><a href="#cite_note-afd-81"><span class="cite_crochet">[</span>81<span class="cite_crochet">]</span></a></sup><sup class="reference cite_virgule">,</sup><sup id="cite_ref-Atlas_interactifAtlas_interactifix_99-0" class="reference"><a href="#cite_note-Atlas_interactifAtlas_interactifix-99"><span class="cite_crochet">[</span>99<span class="cite_crochet">]</span></a></sup>. Le <a href="/wiki/Parc_national_de_la_Lop%C3%A9" title="Parc national de la Lopé">parc national de la Lopé</a> est inscrit sur la liste du patrimoine mondial de l'UNESCO<sup id="cite_ref-unesco_100-0" class="reference"><a href="#cite_note-unesco-100"><span class="cite_crochet">[</span>100<span class="cite_crochet">]</span></a></sup>.
</p>
<table class="wikitable sortable centre jquery-tablesorter">
<caption>Parcs nationaux au Gabon<sup id="cite_ref-101" class="reference"><a href="#cite_note-101"><span class="cite_crochet">[</span>101<span class="cite_crochet">]</span></a></sup>
</caption>
<thead></thead><tbody><tr>
<th scope="col">Parc national
</th>
<th scope="col">Province
</th>
<th scope="col">Superficie
</th>
<th scope="col">Type de paysage
</th>
<td rowspan="14"><table class="DebutCarte" style="width:auto; margin:0; border:none; border-spacing:0; padding:0; text-align:center;">
<tbody><tr><td style="border:none; padding:0"><div style="position:relative;;">
<p><span typeof="mw:File"><a href="//commons.wikimedia.org/wiki/File:Gabon_location_map.svg?uselang=fr" class="mw-file-description"><img src="//upload.wikimedia.org/wikipedia/commons/thumb/5/5b/Gabon_location_map.svg/500px-Gabon_location_map.svg.png" decoding="async" width="500" height="464" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/5b/Gabon_location_map.svg/750px-Gabon_location_map.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/5b/Gabon_location_map.svg/1000px-Gabon_location_map.svg.png 2x" data-file-width="1200" data-file-height="1114"></a></span>
</p>
<div style="position:absolute;top:32.564153846153%;left:20.714285714285%;width:0px;height:0px;margin:0;padding:0;line-height:0px;background-color:transparent;"><div style="position:relative;top:-8px;left:-8px;width:16px;height:16px;background-color:transparent;"><span class="mw-default-size noviewer" typeof="mw:File"><span><img alt="Localisation de la ville" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/30/City_locator_1.svg/16px-City_locator_1.svg.png" decoding="async" width="16" height="16" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/30/City_locator_1.svg/24px-City_locator_1.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/30/City_locator_1.svg/32px-City_locator_1.svg.png 2x" data-file-width="16" data-file-height="16"></span></span></div><div style="position:relative;top:-17px;"><div style="font-size:120%;position:relative;top:-0.80em;left:-12.6em;text-align:right;width:12em;line-height:1.2em;"><span class="toponyme"><b><a href="/wiki/Libreville" title="Libreville">Libreville</a></b></span></div></div></div>
<div style="position:absolute;top:41.419384615384%;left:26.640099999999%;"><div style="position:absolute;top:0px;left:-400px;width:800px;height:0px; line-height:0px;text-align:center;"><span class="toponyme"><span style="font-weight:bold"><a href="/wiki/Estuaire_(province)" title="Estuaire (province)">Estuaire</
nbsp;<abbr class="abbr" title="kilomètre carré">km<sup>2</sup></abbr>
</td>
<td>Côte sableuse
</td></tr>
<tr>
<td><a href="/wiki/Parc_national_de_Mink%C3%A9b%C3%A9" title="Parc national de Minkébé">Minkébé</a>
</td>
<td><a href="/wiki/Woleu-Ntem" title="Woleu-Ntem">Woleu-Ntem</a>
</td>
<td align="right">7&nbsp;560&nbsp;<abbr class="abbr" title="kilomètre carré">km<sup>2</sup></abbr>
</td>
<td>Forêt équatoriale
</td></tr>
<tr>
<td><a href="/wiki/Parc_national_des_Monts_de_Cristal" title="Parc national des Monts de Cristal">Monts de Cristal</a>
</td>
<td><a href="/wiki/Estuaire_(province)" title="Estuaire (province)">Estuaire</a>
</td>
<td align="right">1&nbsp;200&nbsp;<abbr class="abbr" title="kilomètre carré">km<sup>2</sup></abbr>
</td>
<td>Montagne
</td></tr>
<tr>
<td><a href="/wiki/Parc_national_de_Moukalaba-Doudou" title="Parc national de Moukalaba-Doudou">Moukalaba-Doudou</a>
</td>
<td><a href="/wiki/Nyanga_(Gabon)" title="Nyanga (Gabon)">Nyanga</a>
</td>
<td align="right">4&nbsp;500&nbsp;<abbr class="abbr" title="kilomètre carré">km<sup>2</sup></abbr>
</td>
<td>Forêt équatoriale
</td></tr>
<tr>
<td><a href="/wiki/Parc_national_de_Mwagna" title="Parc national de Mwagna">Mwagna</a>
</td>
<td><a href="/wiki/Ogoou%C3%A9-Ivindo" title="Ogooué-Ivindo">Ogooué-Ivindo</a>
</td>
<td align="right">1&nbsp;160&nbsp;<abbr class="abbr" title="kilomètre carré">km<sup>2</sup></abbr>
</td>
<td>Forêt équatoriale
</td></tr>
<tr>
<td><a href="/wiki/Parc_national_des_plateaux_Bat%C3%A9k%C3%A9" title="Parc national des plateaux Batéké">Plateaux Batéké</a>
</td>
<td><a href="/wiki/Haut-Ogoou%C3%A9" title="Haut-Ogooué">Haut-Ogooué</a>
</td>
<td align="right">2&nbsp;050&nbsp;<abbr class="abbr" title="kilomètre carré">km<sup>2</sup></abbr>
</td>
<td>Forêt équatoriale
</td></tr>
<tr>
<td><a href="/wiki/Parc_national_de_Pongara" title="Parc national de Pongara">Pongara</a>
</td>
<td><a href="/wiki/Estuaire_(province)" title="Estuaire (province)">Estuaire</a>
</td>
<td align="right">870&nbsp;<abbr class="abbr" title="kilomètre carré">km<sup>2</sup></abbr>
</td>
<td>Mangrove, côte sableuse
</td></tr>
<tr>
<td><a href="/wiki/Parc_national_de_la_Waka" title="Parc national de la Waka">Waka</a>
</td>
<td><a href="/wiki/Ngouni%C3%A9" title="Ngounié">Ngounié</a>
</td>
<td align="right">1&nbsp;070&nbsp;<abbr class="abbr" title="kilomètre carré">km<sup>2</sup></abbr>
</td>
<td>Montagne
</td></tr></tbody><tfoot></tfoot></table>

# %%
table_donnees = examen.find_all('table')[10]

# %%
print(table_donnees)
# Out:
# <table class="wikitable sortable centre">
# <caption>Parcs nationaux au Gabon<sup class="reference" id="cite_ref-101"><a href="#cite_note-101"><span class="cite_crochet">[</span>101<span class="cite_crochet">]</span></a></sup>
# </caption>
# <tbody><tr>
# <th scope="col">Parc national
# </th>
# <th scope="col">Province
# </th>
# <th scope="col">Superficie
# </th>
# <th scope="col">Type de paysage
# </th>
# <td rowspan="14"><table class="DebutCarte" style="width:auto; margin:0; border:none; border-spacing:0; padding:0; text-align:center;">
# <tbody><tr><td style="border:none; padding:0"><div style="position:relative;;">
# ...

# %%
table_travail_donnees = examen.find('table', class_= 'wikitable sortable centre')

# %%
print(table_travail_donnees)
# Out:
# <table class="wikitable sortable centre">
# <caption>Parcs nationaux au Gabon<sup class="reference" id="cite_ref-101"><a href="#cite_note-101"><span class="cite_crochet">[</span>101<span class="cite_crochet">]</span></a></sup>
# </caption>
# <tbody><tr>
# <th scope="col">Parc national
# </th>
# <th scope="col">Province
# </th>
# <th scope="col">Superficie
# </th>
# <th scope="col">Type de paysage
# </th>
# <td rowspan="14"><table class="DebutCarte" style="width:auto; margin:0; border:none; border-spacing:0; padding:0; text-align:center;">
# <tbody><tr><td style="border:none; padding:0"><div style="position:relative;;">
# ...

# %%
table_travail_donnees.find_all('th')
# Out:
# [<th scope="col">Parc national
#  </th>,
#  <th scope="col">Province
#  </th>,
#  <th scope="col">Superficie
#  </th>,
#  <th scope="col">Type de paysage
#  </th>]

# %%
titre_Parcs_nationaux = table_travail_donnees.find_all('th')

# %%
titre_Parcs_nationaux
# Out:
# [<th scope="col">Parc national
#  </th>,
#  <th scope="col">Province
#  </th>,
#  <th scope="col">Superficie
#  </th>,
#  <th scope="col">Type de paysage
#  </th>]

# %%
table_titre_Parcs_nationaux = [title.text.strip() for title in titre_Parcs_nationaux]

# %%
print(table_titre_Parcs_nationaux)
# Out:
# ['Parc national', 'Province', 'Superficie', 'Type de paysage']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = table_titre_Parcs_nationaux)

df
# Out:
# Empty DataFrame
# Columns: [Parc national, Province, Superficie, Type de paysage]
# Index: []

# %%
table_travail_donnees.find_all('tr')
# Out:
# [<tr>
#  <th scope="col">Parc national
#  </th>
#  <th scope="col">Province
#  </th>
#  <th scope="col">Superficie
#  </th>
#  <th scope="col">Type de paysage
#  </th>
#  <td rowspan="14"><table class="DebutCarte" style="width:auto; margin:0; border:none; border-spacing:0; padding:0; text-align:center;">
#  <tbody><tr><td style="border:none; padding:0"><div style="position:relative;;">
#  <p><span typeof="mw:File"><a class="mw-file-description" href="/wiki/Fichier:Gabon_location_map.svg"><img class="mw-file-element" data-file-height="1114" data-file-width="1200" decoding="async" height="464" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/5b/Gabon_location_map.svg/500px-Gabon_location_map.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/5b/Gabon_location_map.svg/750px-Gabon_location_map.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/5b/Gabon_location_map.svg/1000px-Gabon_location_map.svg.png 2x" width="500"/></a></span>
#  </p>
# ...

# %%
colonne_donnees = table_travail_donnees.find_all('tr')

# %%
for row in colonne_donnees:
    print(row.find_all('td'))
# Out:
# [<div style="position:relative;;">
# <p><span typeof="mw:File"><a class="mw-file-description" href="/wiki/Fichier:Gabon_location_map.svg"><img class="mw-file-element" data-file-height="1114" data-file-width="1200" decoding="async" height="464" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/5b/Gabon_location_map.svg/500px-Gabon_location_map.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/5b/Gabon_location_map.svg/750px-Gabon_location_map.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/5b/Gabon_location_map.svg/1000px-Gabon_location_map.svg.png 2x" width="500"/></a></span>
# </p>
# ...

# %%
for row in colonne_donnees:
    row_data = row.find_all('td')
    individual_row_data  = [data.text.strip() for data in row_data]
    print(individual_row_data )
# Out:
# ["Libreville\nEstuaire\nHaut-Ogooué\nMoyen-Ogooué\nNgounié\nNyanga\nOgooué-Ivindo\nOgooué-Lolo\nOgooué-Maritime\nWoleu-Ntem\nParc national d'Akanda\nParc national de Birougou\nParc national d'Ivindo\nParc national de Loango\nParc national de Mayumba\nParc national de la Lopé\nParc national de Minkébé\nParc national des Monts de Cristal\nParc national de Moukalaba-Doudou\nParc national de Mwagna\nParc national des plateaux Batéké\nParc national de Pongara\nParc national de la Waka\nRéserve de Wonga Wongué", "Libreville\nEstuaire\nHaut-Ogooué\nMoyen-Ogooué\nNgounié\nNyanga\nOgooué-Ivindo\nOgooué-Lolo\nOgooué-Maritime\nWoleu-Ntem\nParc national d'Akanda\nParc national de Birougou\nParc national d'Ivindo\nParc national de Loango\nParc national de Mayumba\nParc national de la Lopé\nParc national de Minkébé\nParc national des Monts de Cristal\nParc national de Moukalaba-Doudou\nParc national de Mwagna\nParc national des plateaux Batéké\nParc national de Pongara\nParc national de la Waka\nR
# ...

# %%
for row in colonne_donnees:
    row_data = row.find_all('td')
    individual_row_data  = [data.text.strip() for data in row_data]
    
    length = len(df)
    df.loc[length] = individual_row_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 6
#       3 individual_row_data  = [data.text.strip() for data in row_data]
#       5 length = len(df)
# ----> 6 df.loc[length] = individual_row_data
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:849, in _LocationIndexer.__setitem__(self, key, value)
#     846 self._has_valid_setitem_indexer(key)
#     848 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 849 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1825, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1822     indexer, missing = convert_missing_indexer(indexer)
#    1824     if missing:
# -> 1825         self._setitem_with_indexer_missing(indexer, value)
#    1826         return
#    1828 if name == "loc":
# ...

# %%
df
